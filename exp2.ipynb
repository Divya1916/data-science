# %% [markdown]
# <a href="https://colab.research.google.com/github/Divya1916/data-science/blob/main/exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a)matrix operation (using vectorization)

# %%
import numpy as np
m1=np.array([[1,3],[2,6]])
m2=np.array([[0,1],[1,9]])
print("Original 2-d matrix:")
print(m1)
print(m2)

print("Outer product of the two matrix is: ")
result=np.outer(m1,m2)
print(result)
# Out:
# Original 2-d matrix:
# [[1 3]
#  [2 6]]
# [[0 1]
#  [1 9]]
# Outer product of the two matrix is:
# [[ 0  1  1  9]
#  [ 0  3  3 27]
#  [ 0  2  2 18]
#  [ 0  6  6 54]]

# %% [markdown]
# b)Transformation using python

# %%
m=[[1,2],[3,4],[5,6]]
for row in m:
  print(row)
res=[[m[j][i] for j in range(len(m))] for i in range(len(m[0]))]
print("\n")
for row in res:
  print(row)
# Out:
# [1, 2]
# [3, 4]
# [5, 6]
#
#
# [1, 3, 5]
# [2, 4, 6]

# %% [markdown]
# c)SVD using python

# %%
from numpy import array
from scipy.linalg import svd
print("array is: ")
A=array([[1,2],[3,4],[5,6]])
print(A)
u,s,vt=svd(A)
print("u")
print(u)
print("s")
print(s)
print("vt")
print(vt)
# Out:
# array is:
# [[1 2]
#  [3 4]
#  [5 6]]
# u
# [[-0.2298477   0.88346102  0.40824829]
#  [-0.52474482  0.24078249 -0.81649658]
#  [-0.81964194 -0.40189603  0.40824829]]
# s
# [9.52551809 0.51430058]
# vt
# [[-0.61962948 -0.78489445]
#  [-0.78489445  0.61962948]]
