# %% [markdown]
# <a href="https://colab.research.google.com/github/Divya1916/data-science/blob/main/exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s=1
print(type(s))
a="hello"
print(type(a))
b=[1,2]
print(type(b))
c={1:'apple',2:'orange'}
print(type(c))
d=True
print(type(d))
e=1.2
print(type(e))
f={"a","b"}
print(type(f))
g=()
print(type(g))
h=bytes()
print(type(h))
i=bytearray()
print(type(i))
j=range(4)
print(type(j))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>
# <class 'bool'>
# <class 'float'>
# <class 'set'>
# <class 'tuple'>
# <class 'bytes'>
# <class 'bytearray'>
# <class 'range'>
